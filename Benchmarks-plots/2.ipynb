# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Data (Extracted from your NEW cross-validation dataset) ---
methods = ['EA', 'CSP+LDA', 'MDRM', 'RA-MDRM', 'LEA', 'TSA', 'RPA', 'MEKT']

# NEW Mean accuracies based on your cross-validation data
mean_acc_2class = [0.71, 0.67, 0.57, 0.70, 0.72, 0.66, 0.53, 0.75]
mean_acc_4class = [0.53, 0.40, 0.33, 0.48, 0.51, 0.45, 0.32, 0.55]

# NEW Standard deviations based on your cross-validation data
std_dev_2class = [0.11, 0.15, 0.06, 0.11, 0.09, 0.14, 0.05, 0.15]
std_dev_4class = [0.17, 0.14, 0.12, 0.15, 0.15, 0.17, 0.05, 0.19]

# --- Plotting ---
x = np.arange(len(methods))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 7)) # Adjust figure size if needed

# Create bars for 2-class results with error bars
rects1 = ax.bar(x - width/2, mean_acc_2class, width, label='2-Class',
                yerr=std_dev_2class, capsize=5, color='skyblue',
                error_kw=dict(elinewidth=1, ecolor='gray')) # Customize error bars

# Create bars for 4-class results with error bars
rects2 = ax.bar(x + width/2, mean_acc_4class, width, label='4-Class',
                yerr=std_dev_4class, capsize=5, color='lightcoral',
                error_kw=dict(elinewidth=1, ecolor='gray')) # Customize error bars

# --- Add labels, title, and custom x-axis tick labels ---
ax.set_ylabel('Mean Cross-Validation Accuracy')
# Updated Title to reflect Cross-Validation
ax.set_title('Comparison of Mean Accuracies (2-Class vs 4-Class) - BCI Competition IV 2A  - Cross Subject')
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=45, ha="right") # Rotate labels if needed
ax.set_ylim(0, 1.1) # Set y-axis limits (0 to 1 or slightly above)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7) # Add horizontal grid lines

# Optional: Add value labels on top of bars (uncomment if desired)
# ax.bar_label(rects1, padding=3, fmt='%.2f')
# ax.bar_label(rects2, padding=3, fmt='%.2f')

fig.tight_layout() # Adjust layout

# --- Show Plot ---
print("Displaying Plot 1: Mean Cross-Validation Accuracies")
plt.show()


print("\n" + "="*30 + "\n") # Separator

# --- Plot 2: Subject-Level Cross-Validation Accuracies (Overlapping Bars) ---

# Data Reorganization is needed here based on the provided text

# --- Data Reorganization with NEW Cross-Validation DATA ---
methods = ['EA', 'CSP+LDA', 'MDRM', 'RA-MDRM', 'LEA', 'TSA', 'RPA', 'MEKT']
num_methods = len(methods)
num_subjects = 9
subjects = [f'Subject {i+1}' for i in range(num_subjects)]

# Updated data structured as: Method -> Subject -> (2-class Acc, 4-class Acc)
# Based on the provided text dump
data = {
    'EA':       [(0.65, 0.69), (0.59, 0.27), (0.92, 0.74), (0.72, 0.42), (0.53, 0.30), (0.68, 0.42), (0.65, 0.60), (0.83, 0.69), (0.80, 0.62)],
    'CSP+LDA':  [(0.72, 0.55), (0.54, 0.24), (0.92, 0.49), (0.66, 0.33), (0.44, 0.24), (0.55, 0.29), (0.60, 0.34), (0.91, 0.59), (0.69, 0.56)],
    'MDRM':     [(0.62, 0.53), (0.49, 0.24), (0.63, 0.55), (0.67, 0.34), (0.50, 0.25), (0.50, 0.25), (0.53, 0.33), (0.60, 0.26), (0.57, 0.25)],
    'RA-MDRM':  [(0.72, 0.64), (0.54, 0.23), (0.81, 0.62), (0.62, 0.41), (0.62, 0.37), (0.69, 0.32), (0.59, 0.38), (0.87, 0.69), (0.79, 0.61)],
    'LEA':      [(0.73, 0.64), (0.56, 0.26), (0.83, 0.67), (0.69, 0.41), (0.65, 0.35), (0.70, 0.37), (0.66, 0.61), (0.86, 0.70), (0.78, 0.61)],
    'TSA':      [(0.64, 0.64), (0.43, 0.20), (0.79, 0.68), (0.65, 0.29), (0.44, 0.32), (0.69, 0.35), (0.71, 0.41), (0.84, 0.62), (0.76, 0.57)],
    'RPA':      [(0.49, 0.38), (0.46, 0.25), (0.62, 0.34), (0.55, 0.31), (0.53, 0.24), (0.47, 0.29), (0.51, 0.34), (0.58, 0.33), (0.60, 0.40)],
    'MEKT':     [(0.87, 0.72), (0.50, 0.23), (0.95, 0.80), (0.74, 0.45), (0.58, 0.33), (0.69, 0.40), (0.64, 0.56), (0.94, 0.78), (0.81, 0.65)],
}

# --- Plotting Calculations ---
# (These calculations remain the same)
bar_width = 0.8
subject_padding = 0.2
method_group_padding = 1.0

x_coords_center = []
tick_coords = [] # For method labels
tick_labels = []
current_pos = 0

for i_method, method in enumerate(methods):
    method_start_pos = current_pos
    for i_subject in range(num_subjects):
        subject_center = current_pos + bar_width / 2
        x_coords_center.append(subject_center)
        current_pos += bar_width + subject_padding
    method_end_pos = current_pos - subject_padding
    method_center_pos = (method_start_pos + method_end_pos) / 2
    tick_coords.append(method_center_pos)
    tick_labels.append(method)
    current_pos += method_group_padding


# --- Plotting ---
fig2, ax2 = plt.subplots(figsize=(20, 7)) # Adjust figure size, use different fig/ax names

# Flatten data for plotting
acc_2class = [data[m][s][0] for m in methods for s in range(num_subjects)]
acc_4class = [data[m][s][1] for m in methods for s in range(num_subjects)]

# Plot the 2-class bars (bottom layer, fully opaque)
bars1 = ax2.bar(x_coords_center, acc_2class, bar_width,
               label='2-Class (Base)', color='lightblue', edgecolor='blue', linewidth=0.5)

# Plot the 4-class bars (top layer, semi-transparent)
bars2 = ax2.bar(x_coords_center, acc_4class, bar_width, # Same positions and width
               label='4-Class (Overlay)', color='salmon', alpha=0.7) # ALPHA makes it transparent


# --- Add labels, title, ticks, etc. ---
# (These settings remain the same, but updated title/label)
ax2.set_ylabel('Cross-Validation Accuracy')
ax2.set_title('Subject-Level Cross-Validation Accuracy: 4-Class (Transparent Overlay) vs 2-Class (Base)')
ax2.set_ylim(0, 1.1)
ax2.legend(title='Class Type')
ax2.grid(axis='y', linestyle='--', alpha=0.7)

ax2.set_xticks(tick_coords)
ax2.set_xticklabels(tick_labels, rotation=30, ha='right')

# Add separator lines between methods
for i in range(num_methods - 1):
     separator_pos = tick_coords[i] + (tick_coords[i+1] - tick_coords[i]) / 2
     ax2.axvline(separator_pos, color='grey', linestyle='--', linewidth=0.8)


fig2.tight_layout()

# --- Show Plot ---
print("Displaying Plot 2: Subject-Level Cross-Validation Accuracies")
plt.show()
# Out:
# Displaying Plot 1: Mean Cross-Validation Accuracies
# ...
#
# Displaying Plot 2: Subject-Level Cross-Validation Accuracies
